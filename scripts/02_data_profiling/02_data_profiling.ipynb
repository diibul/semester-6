# %% [markdown]
# # Tahap 2 — Data Profiling
# **Minggu 3–4 | Muhammad Iqbal Fadel (202310370311268)**
#
# Menganalisis kondisi awal dataset: duplikat, missing values, noise, distribusi panjang teks, dan kata gaul yang ditemukan.

# %%
import sys
from pathlib import Path

# Arahkan ke root project
ROOT_DIR = Path().resolve().parent.parent
sys.path.insert(0, str(ROOT_DIR))

print(f'Root: {ROOT_DIR}')

# %%
# Jalankan pipeline data profiling
import importlib.util, os

script = ROOT_DIR / 'scripts' / '02_data_profiling' / 'profiling.py'
spec = importlib.util.spec_from_file_location('profiling', script)
mod  = importlib.util.module_from_spec(spec)
spec.loader.exec_module(mod)

df = mod.main()

# %%
# Tampilkan sampel data
if df is not None:
    print(f'Total baris valid: {len(df):,}')
    display(df[['USERNAME', 'REVIEW']].head(10))

# %% [markdown]
# ## Hasil
#
# - Laporan tersimpan di: `results/reports/profiling_report.txt`
# - Grafik tersimpan di: `results/figures/` (noise_overview, top_kata_raw, wordcloud_before, dll.)
